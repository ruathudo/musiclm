# %%
import json
from typing import List, Dict, Any
import os
import pandas as pd
from pandas_parallel_apply import DataFrameParallel
from fractions import Fraction
from music21 import converter, chord, note, instrument, tempo, stream, harmony, roman

# %%
DATA_PATH = os.path.join('data', 'MidiCaps')

# %%
def quantize_rational(offset, quarterLength):
    onset = Fraction(offset).limit_denominator(32)
    duration = Fraction(quarterLength).limit_denominator(32)
    return {
        "onset": f"{onset.numerator}/{onset.denominator}",
        "duration": f"{duration.numerator}/{duration.denominator}",
    }

def get_chord_name(el: chord.Chord) -> str:
    """
    Extract a symbolic chord name from a music21 chord element.
    Falls back to root + quality if symbolic name is not available.
    """
    if not isinstance(el, chord.Chord):
        return None

    try:
        # Try symbolic chord naming
        csym = harmony.chordSymbolFigureFromChord(el, includeChordType=True)
        if csym and csym.figure:
            return csym.figure
    except Exception:
        pass

    try:
        # Fallback: root + quality
        root = el.root().name if el.root() else el.bass().name
        quality = el.quality  # e.g., 'major', 'minor', 'dominant', etc.

        # Normalize common qualities to standard suffixes
        quality_map = {
            'major': '',
            'minor': 'm',
            'dominant': '7',
            'diminished': 'dim',
            'augmented': 'aug',
            'half-diminished': 'm7b5',
            'major-seventh': 'maj7',
        }

        suffix = quality_map.get(quality, f"({quality})")
        return f"{root}{suffix}"
    except Exception:
        return None

def extract_notes(part, key_signature, measure_offset=0):
    measures = []


    for i, m in enumerate(part.recurse().getElementsByClass(stream.Measure), start=1):
        measure_notes = []

        flat_notes = m.recurse().getElementsByClass((note.Note, chord.Chord, note.Rest))

        for el in flat_notes:
            if isinstance(el, note.Note):
                scale_deg = key_signature.getScale().getScaleDegreeFromPitch(el.pitch)
                note_data = {
                    "type": "note",
                    "name": el.pitch.name,
                    "pitch": el.pitch.nameWithOctave,
                    "scale_degree": scale_deg or 0,
                    **quantize_rational(el.offset, el.quarterLength),
                    "velocity": el.volume.velocity
                }
                measure_notes.append(note_data)
            elif isinstance(el, chord.Chord):
                try:
                    rn = roman.romanNumeralFromChord(el, key_signature)
                except Exception:
                    rn = None

                chord_name = get_chord_name(el) or el.pitchedCommonName
                #voicing_oct = estimate_voicing_octave(c, root_octave)

                chord_data = {
                    "type": "chord",
                    "name": chord_name,
                    "pitches": [p.nameWithOctave for p in el.pitches],
                    #"notes": [p.name for p in el.pitches],
                    "function": get_function_from_roman(rn.figure),
                    "roman": rn.figure if rn else "unknown",
                    "scale_degrees": get_scale_degrees(el, key_signature),
                    **quantize_rational(el.offset, el.quarterLength),
                    "velocity": el.volume.velocity
                }
                measure_notes.append(chord_data)
            elif isinstance(el, note.Rest):
                rest_data = {
                    "type": "rest",
                    "name": el.fullName,
                    **quantize_rational(el.offset, el.quarterLength),
                }
                measure_notes.append(rest_data)

        measures.append({
            "measure_number": i + measure_offset,
            "notes": measure_notes
        })
    return measures

def get_function_from_roman(rn_figure: str) -> str:
    rn = rn_figure.lower()

    if rn.startswith("it6") or rn.startswith("ger") or rn.startswith("fr") or rn.startswith("sw"):
        return "augmented_sixth"
    if rn.startswith("bii"):
        return "neapolitan"
    if "/" in rn:
        return "secondary_dominant"
    if rn.startswith("v") or rn.startswith("vii"):
        return "dominant"
    if rn.startswith("ii") or rn.startswith("iv"):
        return "subdominant"
    if rn.startswith("i") or rn.startswith("iii") or rn.startswith("vi"):
        return "tonic"
    if rn.startswith("bvi") or rn.startswith("bvii"):
        return "modal_interchange"
    if rn.startswith("#vii") or rn.startswith("#vi") or rn.startswith("#vio"):
        return "chromatic"

    return "other"

def estimate_voicing_octave(chord_obj, root_octave, min_octave=2, max_octave=6):
    if not chord_obj.notes:
        return None
    avg_pitch = sum(p.midi for p in chord_obj.pitches) / len(chord_obj.pitches)
    estimated_octave = int(avg_pitch // 12) - 1  # MIDI pitch 60 = C4 => octave 4
    if estimated_octave < min_octave or estimated_octave > max_octave:
        return root_octave  # invalid range, fallback
    return estimated_octave

def get_scale_degrees(chord, key_signature):
    scale_degrees = [
        (p.diatonicNoteNum - key_signature.tonic.diatonicNoteNum + 1) % 7 or 7
        for p in chord.pitches
    ]
    return scale_degrees

def extract_harmony_chords(score, key_signature, root_octave=4):
    harmony_data = []

    for measure in score.parts[0].getElementsByClass('Measure'):
        for element in measure.notesAndRests:
            if isinstance(element, chord.Chord):
                c = element
                try:
                    rn = roman.romanNumeralFromChord(c, key_signature)
                except Exception:
                    continue

                #voicing_oct = estimate_voicing_octave(c, root_octave)

                harmony_block = {
                    "measure_number": measure.measureNumber,
                    "chord": c.pitchedCommonName,
                    "harmony": {
                        "function": get_function_from_roman(rn.figure),
                        "roman": rn.figure,
                        "scale_degrees": get_scale_degrees(c, key_signature)
                    }
                }
                harmony_data.append(harmony_block)
                break  # assume one harmony per measure
    return harmony_data




# def quantize_onset(value: Fraction, beats_per_measure: int, threshold: Fraction = Fraction(1, 64)) -> Fraction:
#     allowed = []
#     for beat in range(beats_per_measure):
#         for div in [1, 2, 3, 4, 6, 8, 12, 16]:
#             candidate = Fraction(beat) + Fraction(1, div)
#             if candidate < beats_per_measure:
#                 allowed.append(candidate)

#     closest = min(allowed, key=lambda x: abs(x - value))
#     return closest if abs(closest - value) <= threshold else value  # Return None if no close match
# Allowed onset and duration grids for common time signatures
def get_default_resolution(time_signature: str) -> int:
    ts = time_signature.strip()
    if ts in {"6/8", "9/8", "12/8"}:
        return 12  # compound meters benefit from triplet divisions
    elif ts in {"3/4", "4/4", "2/4"}:
        return 16  # standard binary meters
    else:
        return 8  # fallback for uncommon meters

def generate_allowed_onsets(time_signature: str):
    beats_per_measure = int(time_signature.split('/')[0])
    resolution = get_default_resolution(time_signature)

    return [Fraction(i, resolution) for i in range(beats_per_measure * resolution)]

def generate_allowed_durations(time_signature: str, max_measures: int = 2):
    beats_per_measure = int(time_signature.split('/')[0])
    resolution = get_default_resolution(time_signature)

    max_beats = beats_per_measure * max_measures * resolution
    return [Fraction(i, resolution) for i in range(1, max_beats + 1)]

def quantize_onset(value: Fraction, time_signature: str) -> Fraction:
    allowed = generate_allowed_onsets(time_signature)

    #onset_frac = Fraction(value).limit_denominator(64)
    nearest = min(allowed, key=lambda x: abs(x - value))

    return nearest

def quantize_duration(value: Fraction, time_signature: str) -> Fraction:
    allowed = generate_allowed_durations(time_signature, max_measures=2)

    #duration_frac = Fraction(value).limit_denominator(64)
    nearest = min(allowed, key=lambda x: abs(x - value))
    
    return nearest


def apply_swing_correction(genres, onset, duration):
    swing_genres = {"jazz", "blues", "swing", "boogie-woogie"}
    is_swing = any(tag.lower() in swing_genres for tag in genres)

    if is_swing and duration == Fraction(1, 8):
        position_in_beat = onset % 1
        eighth_index = round(position_in_beat * 8)
        is_first_eighth = eighth_index % 2 == 0
        new_duration = Fraction(2, 3) if is_first_eighth else Fraction(1, 3)
        swing_onset = onset if is_first_eighth else onset - Fraction(1, 8) + Fraction(2, 3)
        return swing_onset, new_duration

    return onset, duration

def quantize_chords_from_timestamps(
    timestamps: List[float],
    chords: List[str],
    bpm: float,
    time_signature: str,
) -> List[Dict]:
    """
    timestamps: list of chord start times (in seconds)
    chords: list of chord labels (same length as timestamps)
    bpm: fixed tempo in BPM
    time_signature: time signature from metadata
    """
    assert len(timestamps) == len(chords), "Timestamps and chords must match in length."
    
    seconds_per_beat = 60.0 / bpm
    beats_per_measure = int(time_signature.split('/')[0])

    print("Beats per measure:", beats_per_measure)
    print("Seconds per beat:", seconds_per_beat)

    durations_sec = []
    quantized = []

    # First pass: compute all known durations
    for i in range(len(chords) - 1):
        durations_sec.append(timestamps[i + 1] - timestamps[i])

    # Estimate fallback duration for final chord
    last_chord_duration = durations_sec[-1] if durations_sec else seconds_per_beat * 2
    durations_sec.append(last_chord_duration)

    print(f"start_time --- beat_onset --- relative_onset --- onset_q")
    for i in range(len(chords)):
        chord = chords[i]
        start_time = timestamps[i]
        # end_time = timestamps[i + 1] if i + 1 < len(chords) else start_time + fallback_duration_sec
        duration_sec = durations_sec[i]

        # Calculate beat onset and duration in beats
        # Use Fraction to avoid floating point precision issues
        onset_beats = start_time / seconds_per_beat #Fraction() #.limit_denominator(64)
        duration_beats = duration_sec / seconds_per_beat #.limit_denominator(64)
        # Quantize beat onset and duration to the nearest allowed fraction
        relative_onset = onset_beats % beats_per_measure
        onset_q = quantize_onset(relative_onset, time_signature)
        duration_q = quantize_duration(duration_beats, time_signature)
        print(f"{start_time} --- {onset_beats} --- {relative_onset} --- {onset_q}")
        measure = int(onset_beats) // beats_per_measure + 1

        quantized.append({
            "measure": measure,
            "chord": chord,
            "onset": f"{onset_q.numerator}/{onset_q.denominator}",
            "duration": f"{duration_q.numerator}/{duration_q.denominator}"
        })

    # Group by measure
    grouped = {}
    for entry in quantized:
        key = (entry.pop("measure"))
        grouped.setdefault(key, []).append(entry)

    return [
        {"measure": m, "chords": grouped[m]}
        for m in sorted(grouped)
    ]


def extract_tracks(score):
    extracted_parts = []

    for part in score.parts:
        flat = part.recurse().getElementsByClass(stream.Voice)
        has_voices = any(isinstance(el, stream.Voice) for el in flat)
        print("voices:", flat)
        print("has_voices:", has_voices)
        if has_voices:
            voice_parts = part.voicesToParts()
            if voice_parts:
                extracted_parts.extend(voice_parts)
            else:
                extracted_parts.append(part)
        else:
            extracted_parts.append(part)

    return extracted_parts

def midi_to_json_schema(sample):
    file_hash = sample['location'].split('/')[-1].split('.')[0]
    score = converter.parse(os.path.join(DATA_PATH, sample['location']))
    # score.show('text')
    key_sig = score.analyze('key')

    json_data = {
        "metadata": {
            "tempo": int(sample['tempo']),
            "time_signature": sample['time_signature'],
            "key_signature": str(key_sig),
            # "root_octave": 4
        },
        "chords": sample['chord_summary'],
        "tracks": []
    }

    # parts = extract_tracks(score)

    for i, part in enumerate(score.parts):
        inst = part.recurse().getElementsByClass(instrument.Instrument)

        if inst:
            inst_name = inst[0].instrumentAbbreviation or inst[0].bestName()
        else:
            inst_name = "unknown"
        
        track_data = {
            "name": part.partName or f"track_{i}",
            "instrument": inst_name,
            "measures": extract_notes(part, key_sig)
        }
        json_data["tracks"].append(track_data)

    return {"midi": file_hash, "caption": sample['caption'], "data": json.dumps(json_data)}


def parse_batch_json(df: pd.DataFrame) -> List[Dict[str, Any]]:
    json_data = DataFrameParallel(df, n_cores=30, pbar=True).apply(midi_to_json_schema, axis=1)
    # data_list = [json.loads(json.dumps(data)) for data in json_data]
    return json_data

def parse_json(sample):
    timestamps = sample['all_chords_timestamps']
    chords = sample['all_chords']
    tempo = sample['tempo']
    time_signature = sample['time_signature']

    # print(time_signature)

    chords_formatted = quantize_chords_from_timestamps(timestamps, chords, tempo, time_signature)


    return chords_formatted

# %%
df = pd.read_json('data/MidiCaps/train_filtered.json', lines=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13904 entries, 0 to 13903
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   location                   13904 non-null  object
#  1   caption                    13904 non-null  object
#  2   genre                      13904 non-null  object
#  3   genre_prob                 13904 non-null  object
#  4   mood                       13904 non-null  object
#  5   mood_prob                  13904 non-null  object
#  6   key                        13904 non-null  object
#  7   time_signature             13904 non-null  object
#  8   tempo                      13904 non-null  int64
#  9   tempo_word                 13904 non-null  object
#  10  duration                   13904 non-null  int64
#  11  duration_word              13904 non-null  object
#  12  chord_summary              13904 non-null  object
# ...

# %%
df.iloc[0]
# Out:
# location                       lmd_full/1/17655598958db48a34cd882f81402568.mid
# caption                      A short electronic ambient song featuring a pi...
# genre                                                    [electronic, ambient]
# genre_prob                                       [0.30310000000000004, 0.2369]
# mood                                    [film, energetic, melodic, epic, dark]
# mood_prob                    [0.11620000000000001, 0.11080000000000001, 0.1...
# key                                                                    E major
# time_signature                                                             4/4
# tempo                                                                      170
# tempo_word                                                              Presto
# duration                                                                    99
# duration_word                                                       Short song
# ...

# %%
sample = df.iloc[5]
schema = midi_to_json_schema(sample)

# %%
schema
# Out:
# {'midi': '118dc7024ff75b0bc860f7033dc24982',
#  'caption': 'A very short fragment of energetic electronic music with a piano playing a single F, Fm, E, Em chord sequence at a fast tempo in C major and 4/4 time signature.',
# ...

# %%
final_data = parse_batch_json(df)
# Out:
# /home/qduong/Projects/musiclm/.venv/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# Process-0:   0%|          | 0/449 [00:00<?, ?it/s]
#  ... (more hidden) ...[A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /home/qduong/Projects/musiclm/.venv/lib/python3.11/site-packages/music21/midi/translate.py:922: TranslateWarning: Unable to determine instrument from <music21.midi.MidiEvent SEQUENCE_TRACK_NAME, track=4, data=b'Copyright \xa9 2002 by Bernd Krueger'>; getting generic Instrument
#   warnings.warn(
#
#
#
#
#
#
#
#
# /home/qduong/Projects/musiclm/.venv/lib/python3.11/site-packages/music21/midi/translate.py:1943: TranslateWarning: Unable to decode lyrics from <music21.midi.MidiEvent LYRIC, track=0, data=b'da\xdf '> as utf-8
#   warnings.warn(
# ...

# %%
# final_dict = final_data.to_list()

# %%
# final_dict

# %%
final_data_clean = final_data.to_json(lines=True, orient='records').replace('\/', '/')

with open("data/MidiCaps/train_parsed.json", "w") as f:
    f.write(final_data_clean)

# %%
#final_data.to_json('data/MidiCaps/train_parsed.json', lines=True, orient='records')

# %%
parse_json(df.iloc[1])

# %%
df.head()
# Out:
#                                           location  \
# 0  lmd_full/1/17655598958db48a34cd882f81402568.mid
# 1  lmd_full/1/180b3a492c1c1a46d005e762d62b9aa4.mid
# 2  lmd_full/1/1f94f64f72af98fd92f206293b281f6f.mid
# 3  lmd_full/1/112139e8b17be9cae1bd14df56e52f14.mid
# 4  lmd_full/1/1a20c7ecf60469366d1121ea48fd3f6e.mid
#
#                                              caption                    genre  \
# 0  A short electronic ambient song featuring a pi...    [electronic, ambient]
# 1  A cheerful pop song with a touch of electronic...        [pop, electronic]
# 2  A classical piece that could be part of a film...  [classical, soundtrack]
# 3  A short fragment of energetic electronic and c...  [electronic, classical]
# 4  A short classical piece with electronic elemen...  [classical, electronic]
#
#                                    genre_prob  \
# 0               [0.30310000000000004, 0.2369]
# 1                            [0.4238, 0.2548]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18587 entries, 0 to 18586
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   location                   18587 non-null  object
#  1   caption                    18587 non-null  object
#  2   genre                      18587 non-null  object
#  3   genre_prob                 18587 non-null  object
#  4   mood                       18587 non-null  object
#  5   mood_prob                  18587 non-null  object
#  6   key                        18587 non-null  object
#  7   time_signature             18587 non-null  object
#  8   tempo                      18587 non-null  int64
#  9   tempo_word                 18587 non-null  object
#  10  duration                   18587 non-null  int64
#  11  duration_word              18587 non-null  object
#  12  chord_summary              18587 non-null  object
# ...

# %%
samples = df.sample(10)

# %%
#midi_file = os.path.join(DATA_PATH, samples.iloc[0]['location'])


# with open(os.path.join('data', 'output.json'), "w") as f:
#     json.dump(schema, f, indent=2)

# %%
{
  "time_signature": "4/4",
  "bpm": 120,
  "key_signature": "C",
  "root_octave": 4,
  "harmony_rhythm_pattern": [
    { "onset": "0/4", "duration": "1/4" },
    { "onset": "2/4", "duration": "1/4" }
  ],
  "tracks": [
    {
      "name": "melody",
      "instrument": "piano",
      "measures": [
        {
          "measure_number": 1,
          "notes": [
            {
              "pitch": 64,
              "scale_degree": 3,
              "pitch_class": "E",
              "duration": "1/4",
              "onset": "0/4",
              "velocity": 90
            },
            {
              "pitch": 67,
              "scale_degree": 5,
              "pitch_class": "G",
              "duration": "1/4",
              "onset": "1/4",
              "velocity": 85
            }
          ]
        }
      ]
    },
    {
      "name": "lead",
      "instrument": "violin",
      "measures": [
        {
          "measure_number": 1,
          "notes": [
            {
              "pitch": 64,
              "scale_degree": 3,
              "pitch_class": "E",
              "duration": "1/4",
              "onset": "0/4",
              "velocity": 90
            },
            {
              "pitch": 67,
              "scale_degree": 5,
              "pitch_class": "G",
              "duration": "1/4",
              "onset": "1/4",
              "velocity": 85
            }
          ]
        }
      ]
    },
    {
      "name": "harmony",
      "instrument": "pad",
      "measures": [
        {
          "measure_number": 1,
          "harmonies": [
            {
              "onset": "0/4",
              "duration": "2/4",
              "chord": "C",
              "harmony": {
                "function": "tonic",
                "roman": "I",
                "scale_degrees": [1, 3, 5],
                "voicing_octave": 3
              }
            },
            {
              "onset": "2/4",
              "duration": "2/4",
              "chord": "G7",
              "harmony": {
                "function": "dominant",
                "roman": "V7",
                "scale_degrees": [1, 3, 5, "flat7"],
                "voicing_octave": 3
              }
            }
          ]
        }
      ]
    }
  ]
}

# %%
[
  {
    "measure": 1,
    "chords": [
      { "chord": "B", "onset": "0/1", "duration": "1/2" },
      { "chord": "Emaj7", "onset": "1/2", "duration": "1/2" }
    ]
  },
  {
    "measure": 2,
    "chords": [
      { "chord": "C#m7", "onset": "0/1", "duration": "1/2" },
      { "chord": "B7", "onset": "1/2", "duration": "1/2" }
    ]
  },
  {
    "measure": 3,
    "chords": [
      { "chord": "A", "onset": "0/1", "duration": "1/1" }
    ]
  },
  {
    "measure": 4,
    "chords": [
      { "chord": "B", "onset": "0/1", "duration": "1/1" }
    ]
  },
  {
    "measure": 5,
    "chords": [
      { "chord": "Emaj7", "onset": "0/1", "duration": "1/1" }
    ]
  }
]

# %%
schema
# Out:
# {'metadata': {'title': 'Converted MIDI',
#   'composer': 'Unknown',
#   'bpm': 190,
#   'time_signature': '4/4',
#   'key_signature': 'g# minor',
#   'root_octave': 4},
#  'tracks': [{'name': 'track_0',
#    'instrument': 'piano',
#    'measures': [{'measure_number': 11,
#      'notes': [{'pitch': 73,
#        'pitch_class': 'C#',
#        'scale_degree': 2,
#        'onset': {'numerator': 0, 'denominator': 1},
#        'duration': {'numerator': 1, 'denominator': 2},
#        'velocity': 100}]},
#     {'measure_number': 15,
#      'notes': [{'pitch': 73,
#        'pitch_class': 'C#',
#        'scale_degree': 2,
#        'onset': {'numerator': 0, 'denominator': 1},
#        'duration': {'numerator': 1, 'denominator': 2},
#        'velocity': 100}]},
#     {'measure_number': 25,
#      'notes': [{'pitch': 63,
#        'pitch_class': 'E-',
#        'scale_degree': None,
#        'onset': {'numerator': 0, 'denominator': 1},
#        'duration': {'numerator': 4, 'denominator': 1},
# ...
